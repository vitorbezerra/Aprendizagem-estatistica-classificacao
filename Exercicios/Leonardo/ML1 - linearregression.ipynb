# %% [markdown]
# # Exercicio 1
# * Treine modelos lineares na base Portland utilizando apenas um dos atributos preditores

# %%
import sklearn
import pandas as pd
from sklearn import linear_model
from sklearn import datasets
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
data_raw_1 = pd.read_csv('Advertising.csv', sep =',', index_col=None)
data_raw_2 = pd.read_csv('ex1data2.txt', sep=',', index_col=None)
data_1 = data_raw_1.copy(deep=True)
data_2 = data_raw_2.copy(deep=True)
print('*'*50)
print(data_raw_1.head())
print('*'*50)
print(data_raw_2.head())
print('*'*50)
# Out:
# **************************************************
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9
# **************************************************
#    tamanho  quartos   preco
# 0     2104        3  399900
# 1     1600        3  329900
# 2     2400        3  369000
# 3     1416        2  232000
# 4     3000        4  539900
# **************************************************

# %%
from sklearn.model_selection import train_test_split;
reg = linear_model.LinearRegression()

train_x, test_x, train_y, test_y = train_test_split(data_1.loc[:,['TV']], data_1.loc[:,['sales']])
reg.fit(train_x, train_y)

y_pred = reg.predict(test_x) 
#------Coeficientes----------
print('Coeficiente:', reg.coef_)
print('Erro quadratico medio: %.2f' % mean_squared_error(test_y,y_pred))
print('Coeficiente de determinacao: %.2f' % r2_score(test_y, y_pred))
#-----------plot-----------
f = plt.figure()
plt.plot(test_x,y_pred, label='Linear_Model', c='k')
plt.scatter(train_x,train_y, label='Distribuicao', c='r')
plt.legend()
plt.show()
print(train_x, train_y)
# Out:
# Coeficiente: [[0.04459843]]
# Erro quadratico medio: 12.57
# Coeficiente de determinacao: 0.63
#         TV
# 105  137.9
# 71   109.8
# 100  222.4
# 57   136.2
# 136   25.6
# ..     ...
# 171  164.5
# 56     7.3
# 106   25.0
# 83    68.4
# 39   228.0
#
# [150 rows x 1 columns]      sales
# 105   19.2
# 71    12.4
# 100   11.7
# 57    13.2
# 136    9.5
# ..     ...
# 171   14.5
# 56     5.5
# 106    7.2
# 83    13.6
# 39    21.5
#
# [150 rows x 1 columns]

# %%
train_x, test_x, train_y, test_y = train_test_split(data_1.loc[:,['radio']], data_1.loc[:,['sales']])
reg.fit(train_x, train_y)

y_pred = reg.predict(test_x) 
#------Coeficientes----------
print('Coeficiente:', reg.coef_)
print('Erro quadratico medio: %.2f' % mean_squared_error(test_y,y_pred))
print('Coeficiente de determinacao: %.2f' % r2_score(test_y, y_pred))
#-----------plot-----------
f = plt.figure()
plt.plot(test_x,y_pred, label='Linear_Model', c='k')
plt.scatter(train_x,train_y, label='Distribuicao', c='r')
plt.legend()
plt.show()
# Out:
# Coeficiente: [[0.19813317]]
# Erro quadratico medio: 15.00
# Coeficiente de determinacao: 0.37

# %%
train_x, test_x, train_y, test_y = train_test_split(data_1.loc[:,['newspaper']], data_1.loc[:,['sales']])
reg.fit(train_x, train_y)

y_pred = reg.predict(test_x) 
#------Coeficientes----------
print('Coeficiente:', reg.coef_)
print('Erro quadratico medio: %.2f' % mean_squared_error(test_y,y_pred))
print('Coeficiente de determinacao: %.2f' % r2_score(test_y, y_pred))
#-----------plot-----------
f = plt.figure()
plt.plot(test_x,y_pred, label='Linear_Model', c='k')
plt.scatter(train_x,train_y, label='Distribuicao', c='r')
plt.legend()
plt.show()
# Out:
# Coeficiente: [[0.05899311]]
# Erro quadratico medio: 28.98
# Coeficiente de determinacao: -0.02

# %%
train_x, test_x, train_y, test_y = train_test_split(data_2.loc[:,['tamanho']], data_2.loc[:,['preco']])
reg.fit(train_x, train_y)

y_pred = reg.predict(test_x) 
#------Coeficientes----------
print('Coeficiente:', reg.coef_)
print('Erro quadratico medio: %.2f' % mean_squared_error(test_y,y_pred))
print('Coeficiente de determinacao: %.2f' % r2_score(test_y, y_pred))
#-----------plot-----------
f = plt.figure()
plt.plot(test_x,y_pred, label='Linear_Model', c='k')
plt.scatter(train_x,train_y, label='Distribuicao', c='r')
plt.legend()
plt.show()
# Out:
# Coeficiente: [[142.72749966]]
# Erro quadratico medio: 4393282130.64
# Coeficiente de determinacao: 0.76

# %%
from sklearn.linear_model import SGDRegressor
reg = SGDRegressor(max_iter=5000, alpha=0)

train_x, test_x, train_y, test_y = train_test_split(data_1.loc[:,['TV']], data_1.loc[:,['sales']])
reg.fit(train_x, train_y.values.ravel())

y_pred = reg.predict(test_x) 
#------Coeficientes----------
#print('Coeficiente:', reg.coef_)
#print('Erro quadratico medio: %.2f' % mean_squared_error(test_y,y_pred))
#print('Coeficiente de determinacao: %.2f' % r2_score(test_y, y_pred))
#-----------plot-----------
f = plt.figure()
plt.plot(test_x,y_pred, label='Linear_Model', c='k')
plt.scatter(train_x,train_y, label='Distribuicao', c='r')
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

train_x, test_x, train_y, test_y = train_test_split(data_1.loc[:,['TV']], data_1.loc[:,['sales']])

scaler.fit(train_x)
x_scaled = scaler.transform(train_x)

reg = SGDRegressor(max_iter=3, alpha=0, warm_start=True)

reg.fit(x_scaled, train_y.values.ravel())
 
    
y_pred = reg.predict(x_scaled)    
#------Coeficientes----------
#print('Coeficiente:', reg.coef_)
#print('Erro quadratico medio: %.2f' % mean_squared_error(test_y,y_pred))
#print('Coeficiente de determinacao: %.2f' % r2_score(test_y, y_pred))
#-----------plot-----------
f = plt.figure()
plt.scatter(train_x,train_y, label='Linear_Model', c='k')
plt.plot(train_x,y_pred, label='Distribuicao', c='r')
plt.legend()
plt.show()

# %%
for i in range(10):
    reg.fit(x_scaled, train_y.values.ravel())
    
    
f = plt.figure()
plt.scatter(train_x,train_y, label='Linear_Model', c='k')
plt.plot(train_x,reg.predict(x_scaled), label='Distribuicao', c='r')
plt.legend()
plt.show()

# %%
data_1_tv = data_1.loc[:,['TV']]
data_1_radio = data_1.loc[:,['radio']]
data_1_newspaper = data_1.loc[:,['newspaper']]
data_1_tv_radio = data_1.loc[:,['TV', 'radio']]
data_1_tv_nespaper = data_1.loc[:,['TV','newspaper']]
data_1_radio_newspaper = data_1.loc[:,['radio','newspaper']]
data_1_all = data_1.loc[:,['TV', 'radio', 'newspaper']]
